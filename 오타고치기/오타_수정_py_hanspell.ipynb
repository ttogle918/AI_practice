# %% [markdown]
# <a href="https://colab.research.google.com/github/ttogle918/AI_practice/blob/main/%EC%98%A4%ED%83%80%EA%B3%A0%EC%B9%98%EA%B8%B0/%EC%98%A4%ED%83%80_%EC%88%98%EC%A0%95_py_hanspell.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/ssut/py-hanspell.git
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/ssut/py-hanspell.git to /tmp/pip-req-build-azk6enf8
#   Running command git clone -q https://github.com/ssut/py-hanspell.git /tmp/pip-req-build-azk6enf8
# ...
#   Created wheel for py-hanspell: filename=py_hanspell-1.1-py3-none-any.whl size=4870 sha256=f25a1dd1e005dbaf8e5fa45d427f69f9e22191947716f3c47ffba62a955a00d7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xzt73vxk/wheels/3f/a5/73/e4d2806ae141d274fdddaabf8c0ed79be9357d36bfdc99e4b4
# Successfully built py-hanspell
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 451 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 132 kB 61.8 MB/s
# ...
#      |████████████████████████████████| 182 kB 59.9 MB/s
# ...
#      |████████████████████████████████| 212 kB 55.7 MB/s
# ...
#      |████████████████████████████████| 127 kB 63.1 MB/s
# ...

# %%
from datasets import load_dataset
dataset_squad = load_dataset('squad_kor_v1')
dataset_squad, dataset_squad['train'][1]
# Out:
# ...
# Generating validation split:   0%|          | 0/5774 [00:00<?, ? examples/s]
# Dataset squad_kor_v1 downloaded and prepared to /root/.cache/huggingface/datasets/squad_kor_v1/squad_kor_v1/1.0.0/18d4f44736b8ee85671f63cb84965bfb583fa0a4ff2df3c2e10eee9693796725. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]
# (DatasetDict({
#      train: Dataset({
#          features: ['id', 'title', 'context', 'question', 'answers'],
#          num_rows: 60407
#      })
#      validation: Dataset({
#          features: ['id', 'title', 'context', 'question', 'answers'],
#          num_rows: 5774
#      })
#  }),
#  {'id': '6566495-0-1',
#   'title': '파우스트_서곡',
# ...

# %%
train_text = [data['context'] for data in dataset_squad['train']]
validation_text = [data['context'] for data in dataset_squad['validation']]

# %%
from hanspell import spell_checker

# %%
result = spell_checker.check('1839년 바그너는 괴테의 파우스트을 처음 읽고 그 내용에 마음이 끌려 이를 소재로 해서 하나의 교향곡을 쓰려는 뜻을 갖는다.')
print(result.checked, '\n')
result.as_dict()
# Out:
# 1839년 바그너는 괴테의 파우스트를 처음 읽고 그 내용에 마음이 끌려 이를 소재로 해서 하나의 교향곡을 쓰려는 뜻을 갖는다.
# {'result': True,
#  'original': '1839년 바그너는 괴테의 파우스트을 처음 읽고 그 내용에 마음이 끌려 이를 소재로 해서 하나의 교향곡을 쓰려는 뜻을 갖는다.',
#  'checked': '1839년 바그너는 괴테의 파우스트를 처음 읽고 그 내용에 마음이 끌려 이를 소재로 해서 하나의 교향곡을 쓰려는 뜻을 갖는다.',
#  'errors': 1,
#  'words': OrderedDict([('1839년', 0),
#               ('바그너는', 0),
#               ('괴테의', 0),
#               ('파우스트를', 4),
#               ('처음', 0),
#               ('읽고', 0),
#               ('그', 0),
#               ('내용에', 0),
#               ('마음이', 0),
#               ('끌려', 0),
#               ('이를', 0),
#               ('소재로', 0),
#               ('해서', 0),
#               ('하나의', 0),
#               ('교향곡을', 0),
#               ('쓰려는', 0),
#               ('뜻을', 0),
#               ('갖는다.', 0)]),
#  'time': 0.3108859062194824}

# %%
result = spell_checker.check('이 시기 바그너는 1838년에 빛 독촉으로 산전수전을 다 걲은 상황이라 좌절과 실망에 가득했으며 메피스토펠레스를 만나는 파우스트의 심경에 공감했다고 한다.')
print(result.checked, '\n')
result.as_dict()
# Out:
# 이 시기 바그너는 1838년에 빛 독촉으로 산전수전을 다 걲은 상황이라 좌절과 실망에 가득했으며 메피스토펠레스를 만나는 파우스트의 심경에 공감했다고 한다.
# {'result': True,
#  'original': '이 시기 바그너는 1838년에 빛 독촉으로 산전수전을 다 걲은 상황이라 좌절과 실망에 가득했으며 메피스토펠레스를 만나는 파우스트의 심경에 공감했다고 한다.',
#  'checked': '이 시기 바그너는 1838년에 빛 독촉으로 산전수전을 다 걲은 상황이라 좌절과 실망에 가득했으며 메피스토펠레스를 만나는 파우스트의 심경에 공감했다고 한다.',
#  'errors': 1,
#  'words': OrderedDict([('이', 0),
#               ('시기', 0),
#               ('바그너는', 0),
#               ('1838년에', 0),
#               ('빛', 0),
#               ('독촉으로', 0),
#               ('산전수전을', 0),
#               ('다', 0),
#               ('<span', 0),
#               ("class='violet_text'>걲은", 0),
#               ('상황이라', 0),
#               ('좌절과', 0),
#               ('실망에', 0),
#               ('가득했으며', 0),
#               ('메피스토펠레스를', 0),
#               ('만나는', 0),
#               ('파우스트의', 0),
#               ('심경에', 0),
#               ('공감했다고', 0),
#               ('한다.', 0)]),
#  'time': 0.24097204208374023}

# %%
result = spell_checker.check('또한 파리에서 아브네크의 지휘로 파리 음악원 관현악단이 연주하는 베토벤의 교향곡 9번을 듣고 깊은 감명을 받았는데, 이것이 이듬해 1월에 파우스트의 서곡으로 쓰여진 이 작품에 조금이라도 영향을 끼쳤으리라는 것은 의심할 여지가 없다. ')
result.as_dict()
# Out:
# {'result': True,
#  'original': '또한 파리에서 아브네크의 지휘로 파리 음악원 관현악단이 연주하는 베토벤의 교향곡 9번을 듣고 깊은 감명을 받았는데, 이것이 이듬해 1월에 파우스트의 서곡으로 쓰여진 이 작품에 조금이라도 영향을 끼쳤으리라는 것은 의심할 여지가 없다. ',
#  'checked': '또한 파리에서 아브 네크의 지휘로 파리 음악원 관현악단이 연주하는 베토벤의 교향곡 9번을 듣고 깊은 감명을 받았는데, 이것이 이듬해 1월에 파우스트의 서곡으로 쓰인 이 작품에 조금이라도 영향을 끼쳤으리라는 것은 의심할 여지가 없다. ',
#  'errors': 2,
#  'words': OrderedDict([('또한', 0),
#               ('파리에서', 0),
#               ('아브', 2),
#               ('네크의', 2),
#               ('지휘로', 0),
#               ('파리', 0),
#               ('음악원', 0),
#               ('관현악단이', 0),
#               ('연주하는', 0),
#               ('베토벤의', 0),
#               ('교향곡', 0),
#               ('9번을', 0),
#               ('듣고', 0),
#               ('깊은', 0),
#               ('감명을', 0),
#               ('받았는데,', 0),
#               ('이것이', 0),
#               ('이듬해', 0),
#               ('1월에', 0),
#               ('파우스트의', 0),
#               ('서곡으로', 0),
#               ('쓰인', 1),
#               ('이', 0),
# ...

# %%
result = spell_checker.check('여기의 라단조 조성의 경우에도 그의 전기에 적혀 있는 것처럼 단순한 정신적 피로나 실의가 반영된 것이 아니라 베토벤의 합창교향곡 조성의 영향을 받은 것을 볼 수 있다.')
result.as_dict()
# Out:
# {'result': True,
#  'original': '여기의 라단조 조성의 경우에도 그의 전기에 적혀 있는 것처럼 단순한 정신적 피로나 실의가 반영된 것이 아니라 베토벤의 합창교향곡 조성의 영향을 받은 것을 볼 수 있다.',
#  'checked': '여기의 라단조 조성의 경우에도 그의 전기에 적혀 있는 것처럼 단순한 정신적 피로나 실의가 반영된 것이 아니라 베토벤의 합창교향곡 조성의 영향을 받은 것을 볼 수 있다.',
#  'errors': 0,
#  'words': OrderedDict([('여기의', 0),
#               ('라단조', 0),
#               ('조성의', 0),
#               ('경우에도', 0),
#               ('그의', 0),
#               ('전기에', 0),
#               ('적혀', 0),
#               ('있는', 0),
#               ('것처럼', 0),
#               ('단순한', 0),
#               ('정신적', 0),
#               ('피로나', 0),
#               ('실의가', 0),
#               ('반영된', 0),
#               ('것이', 0),
#               ('아니라', 0),
#               ('베토벤의', 0),
#               ('합창교향곡', 0),
#               ('영향을', 0),
#               ('받은', 0),
#               ('것을', 0),
#               ('볼', 0),
#               ('수', 0),
#               ('있다.', 0)]),
#  'time': 0.19681906700134277}

# %%
result = spell_checker.check('그렇게 교향곡 작곡을 1839년부터 40년에 걸쳐 파리에서 착수했으나 1악장을 쓴 뒤에 중단했다.')
result.as_dict()
# Out:
# {'result': True,
#  'original': '그렇게 교향곡 작곡을 1839년부터 40년에 걸쳐 파리에서 착수했으나 1악장을 쓴 뒤에 중단했다.',
#  'checked': '그렇게 교향곡 작곡을 1839년부터 40년에 걸쳐 파리에서 착수했으나 1악장을 쓴 뒤에 중단했다.',
#  'errors': 0,
#  'words': OrderedDict([('그렇게', 0),
#               ('교향곡', 0),
#               ('작곡을', 0),
#               ('1839년부터', 0),
#               ('40년에', 0),
#               ('걸쳐', 0),
#               ('파리에서', 0),
#               ('착수했으나', 0),
#               ('1악장을', 0),
#               ('쓴', 0),
#               ('뒤에', 0),
#               ('중단했다.', 0)]),
#  'time': 0.1651926040649414}

# %%
result = spell_checker.check('또한 작품의 완성과 동시에 그는 이 서곡(1악장)을 파리 음악원의 연주회에서 연주할 파트보까지 준비하였으나, 실제로는 이루어지지는 않았다.')
result.as_dict()
# Out:
# {'result': True,
#  'original': '또한 작품의 완성과 동시에 그는 이 서곡(1악장)을 파리 음악원의 연주회에서 연주할 파트보까지 준비하였으나, 실제로는 이루어지지는 않았다.',
#  'checked': '또한 작품의 완성과 동시에 그는 이 서곡(1악장)을 파리 음악원의 연주회에서 연주할 파트 봄까지 준비하였으나, 실제로는 이루어지지는 않았다.',
#  'errors': 1,
#  'words': OrderedDict([('또한', 0),
#               ('작품의', 0),
#               ('완성과', 0),
#               ('동시에', 0),
#               ('그는', 0),
#               ('이', 0),
#               ('서곡(1악장)을', 0),
#               ('파리', 0),
#               ('음악원의', 0),
#               ('연주회에서', 0),
#               ('연주할', 0),
#               ('파트', 4),
#               ('봄까지', 4),
#               ('준비하였으나,', 0),
#               ('실제로는', 0),
#               ('이루어지지는', 0),
#               ('않았다.', 0)]),
#  'time': 0.3452465534210205}

# %%
result = spell_checker.check('결국 초연은 4년 반이 지난 후에 드레스덴에서 연주되었고 재연도 이루어졌지만, 이후에 그대로 방치되고 말았다. 그 사이에 그는 리엔치와 방황하는 네덜란드인을 완성하고 탄호이저에도 착수하는 등 분주한 시간을 보냈는데, 그런 바쁜 생활이 이 곡을 잊게 한 것이 아닌가 하는 의견도 있다. 그렇게 교향곡 작곡을 1839년부터 40년에 걸쳐 파리에서 착수했으나 1악장을 쓴 뒤에 중단했다.')
result.as_dict()
# Out:
# {'result': True,
#  'original': '결국 초연은 4년 반이 지난 후에 드레스덴에서 연주되었고 재연도 이루어졌지만, 이후에 그대로 방치되고 말았다. 그 사이에 그는 리엔치와 방황하는 네덜란드인을 완성하고 탄호이저에도 착수하는 등 분주한 시간을 보냈는데, 그런 바쁜 생활이 이 곡을 잊게 한 것이 아닌가 하는 의견도 있다. 그렇게 교향곡 작곡을 1839년부터 40년에 걸쳐 파리에서 착수했으나 1악장을 쓴 뒤에 중단했다.',
#  'checked': '결국 초연은 4년 반이 지난 후에 드레스덴에서 연주되었고 재연도 이루어졌지만, 이후에 그대로 방치되고 말았다. 그 사이에 그는 리에 누치와 방황하는 네덜란드인을 완성하고 탄호이저에도 착수하는 등 분주한 시간을 보냈는데, 그런 바쁜 생활이 이 곡을 잊게 한 것이 아닌가 하는 의견도 있다. 그렇게 교향곡 작곡을 1839년부터 40년에 걸쳐 파리에서 착수했으나 1악장을 쓴 뒤에 중단했다.',
#  'errors': 1,
#  'words': OrderedDict([('결국', 0),
#               ('초연은', 0),
#               ('4년', 0),
#               ('반이', 0),
#               ('지난', 0),
#               ('후에', 0),
#               ('드레스덴에서', 0),
#               ('연주되었고', 0),
#               ('재연도', 0),
#               ('이루어졌지만,', 0),
#               ('이후에', 0),
#               ('그대로', 0),
#               ('방치되고', 0),
#               ('말았다.', 0),
#               ('그', 0),
#               ('사이에', 0),
#               ('그는', 0),
# ...

# %%
result = spell_checker.check('그 사이에 그는 리엔치와 방황하는 네덜란드인을 완성하고 탄호이저에도 착수하는 등 분주한 시간을 보냈는데, 그런 바쁜 생활이 이 곡을 잊게 한 것이 아닌가 하는 의견도 있다.')
result.as_dict()
# Out:
# {'result': True,
#  'original': '그 사이에 그는 리엔치와 방황하는 네덜란드인을 완성하고 탄호이저에도 착수하는 등 분주한 시간을 보냈는데, 그런 바쁜 생활이 이 곡을 잊게 한 것이 아닌가 하는 의견도 있다.',
#  'checked': '그 사이에 그는 리에 누치와 방황하는 네덜란드인을 완성하고 탄호이저에도 착수하는 등 분주한 시간을 보냈는데, 그런 바쁜 생활이 이 곡을 잊게 한 것이 아닌가 하는 의견도 있다.',
#  'errors': 1,
#  'words': OrderedDict([('그', 0),
#               ('사이에', 0),
#               ('그는', 0),
#               ('리에', 4),
#               ('누치와', 4),
#               ('방황하는', 0),
#               ('네덜란드인을', 0),
#               ('완성하고', 0),
#               ('탄호이저에도', 0),
#               ('착수하는', 0),
#               ('등', 0),
#               ('분주한', 0),
#               ('시간을', 0),
#               ('보냈는데,', 0),
#               ('그런', 0),
#               ('바쁜', 0),
#               ('생활이', 0),
#               ('이', 0),
#               ('곡을', 0),
#               ('잊게', 0),
#               ('한', 0),
#               ('것이', 0),
#               ('아닌가', 0),
#               ('하는', 0),
#               ('의견도', 0),
#               ('있다.', 0)]),
# ...

# %%
result = spell_checker.check('그렇게 교향곡 작곡을 1839년부터 40년에 걸쳐 파리에서 착수했으나 1악장을 쓴 뒤에 중단했다.')
result.as_dict()
# Out:
# {'result': True,
#  'original': '그렇게 교향곡 작곡을 1839년부터 40년에 걸쳐 파리에서 착수했으나 1악장을 쓴 뒤에 중단했다.',
#  'checked': '그렇게 교향곡 작곡을 1839년부터 40년에 걸쳐 파리에서 착수했으나 1악장을 쓴 뒤에 중단했다.',
#  'errors': 0,
#  'words': OrderedDict([('그렇게', 0),
#               ('교향곡', 0),
#               ('작곡을', 0),
#               ('1839년부터', 0),
#               ('40년에', 0),
#               ('걸쳐', 0),
#               ('파리에서', 0),
#               ('착수했으나', 0),
#               ('1악장을', 0),
#               ('쓴', 0),
#               ('뒤에', 0),
#               ('중단했다.', 0)]),
#  'time': 0.1729872226715088}
